# %%
import pandas as pd

# %%
nodes_edges_sea = pd.read_csv("nodes_edges_sea.csv")

# %%
nodes_edges_sea
# Out:
#       START_ID                TYPE    END_ID  \
# 0     82140949  registered_address  81068654
# 1     82141151  registered_address  81068712
# 2     82141151  registered_address  81068710
# 3     82141151  registered_address  81068711
# 4     82141151  registered_address  81068713
# 5     82141151  registered_address  81054296
# 6     82131756  registered_address  81000344
# 7     82108506  registered_address  81077575
# 8     82108506  registered_address  81077574
# 9     82101368  registered_address  81029215
# 10    82103635  registered_address  81058652
# 11    82103635  registered_address  81058653
# 12    82083163  registered_address  81081047
# 13    82080713  registered_address  81029712
# 14    82080713  registered_address  81029913
# 15    82076319  registered_address  81081813
# 16    82076804  registered_address  81082291
# 17    82057530  registered_address  81083707
# 18    82057530  registered_address  81076096
# 19    82036363  registered_address  81077833
# ...

# %%
nodes_filt_entity = pd.read_csv("nodes_filt_entity.csv")

# %%
nodes_filt_entity
# Out:
#        node_id                                              name jurisdiction  \
# 0     82070160                Global Crossing Asia Holdings Ltd.           XX
# 1     82026451              Monument Resources Petroleum Limited           BM
# 2     82026459              Xinle International Holdings Limited           BM
# 3     82026466                        CEF MB Investments Limited           BM
# 4     82026443                   Golden Spike Pasiriaman Limited           BM
# 5     82026529                             A P Resources Limited           BM
# 6     82026530                       A P Forest Products Limited           BM
# 7     82036730                          Jobs DB Holdings Limited           BM
# 8     82025054                                HBA Insurance Ltd.           BM
# 9     82025177                           ACB  International Ltd.           BM
# 10    82025261                                   SPO MPV Limited           BM
# ...

# %%
nodes_officer_sea = pd.read_csv("nodes_officer_sea.csv")

# %%
nodes_officer_sea
# Out:
#        node_id                                            name country_codes  \
# 0     80026261                       Grindrod Shipping Pte Ltd           SGP
# 1     80026678                          Abaya, Jr - Antonio N.           PHL
# 2     80026680                 Abbas - Mohamed Yunus Ramli Bin           MYS
# 3     80026735                         Abdul Jalil - Abu Fitri           MYS
# 4     80026749                     Abdul Rahman - Normah Binti           MYS
# 5     80027034                              ACHANTA - Prasanna           SGP
# 6     80027102                      ACOSTA - Francisco Paredes           PHL
# 7     80027204                       Adams - Michael Alexander           PHL
# 8     80027303                 Adiningsih - Siti Hutami Endang           IDN
# 9     80027307                                Aditto - Pravith           THA
# 10    80028225                            Aldridge - Edward W.           SGP
# ...
